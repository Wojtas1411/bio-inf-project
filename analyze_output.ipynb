# %%
import pandas as pd;
import numpy as np;

# %%
dataframe = pd.read_csv("cmake-build-debug/result.csv",sep=";",index_col=0)
dataframe
# Out:
#           filename   time  error type  number of elements  \
# id
# 0        35.200-80  0.004           0                 200
# 1       55.400-160  0.010           0                 400
# 2       58.300+120  0.007           1                 300
# 3        58.300-60  0.004           0                 300
# 4         9.200+80  0.002           1                 200
# 5        68.400-80  0.006           0                 400
# 6        18.200-80  0.003           0                 200
# 7        55.300+30  0.011           1                 300
# 8        35.200+20  0.005           1                 200
# 9       55.400+160  0.021           1                 400
# 10       10.500+50  0.015           1                 500
# 11      20.300-120  0.004           0                 300
# 12        9.200+20  0.007           1                 200
# 13      62.400+160  0.008           1                 400
# 14       18.200+80  0.015           1                 200
# ...

# %%
dataframe.describe()
# Out:
#             time  error type  number of elements  number of elements real  \
# count  54.000000   54.000000           54.000000                54.000000
# mean    0.024426    0.444444         1283.333333              1180.166667
# std     0.125534    0.501570         6755.563745              6066.643036
# min     0.001000    0.000000          200.000000               120.000000
# 25%     0.004000    0.000000          300.000000               240.000000
# 50%     0.006000    0.000000          400.000000               325.000000
# 75%     0.009750    1.000000          500.000000               478.500000
# max     0.929000    1.000000        50000.000000             44921.000000
#
#         error size  used elements    chain size  required size
# count    54.000000      54.000000     54.000000      54.000000
# mean    180.944444    1141.277778   1360.388889    1292.333333
# std     681.690363    6071.274761   6750.457554    6755.563745
# ...
