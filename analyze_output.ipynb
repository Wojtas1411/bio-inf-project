# %%
import pandas as pd;
import numpy as np;

# %%
dataframe = pd.read_csv("cmake-build-debug/result.csv",sep=";",index_col=0)
benchmark = dataframe.loc[dataframe["number of elements"]>1000,:]
dataframe = dataframe.loc[dataframe["number of elements"]<1000,:]
dataframe
# Out:
#       filename   time  error type  number of elements  \
# id
# 0    35.200-80  0.004           0                 200
# 1   55.400-160  0.009           0                 400
# 2   58.300+120  0.015           1                 300
# 3    58.300-60  0.003           0                 300
# 4     9.200+80  0.003           1                 200
# 5    68.400-80  0.005           0                 400
# 6    18.200-80  0.002           0                 200
# 7    55.300+30  0.007           1                 300
# 8    35.200+20  0.003           1                 200
# 9   55.400+160  0.018           1                 400
# 10   10.500+50  0.011           1                 500
# 11  20.300-120  0.003           0                 300
# 12    9.200+20  0.004           1                 200
# 13  62.400+160  0.018           1                 400
# 14   18.200+80  0.008           1                 200
# 15   62.400+40  0.007           1                 400
# ...

# %%
dataframe.describe()
# Out:
#             time  error type  number of elements  number of elements real  \
# count  53.000000   53.000000           53.000000                53.000000
# mean    0.006755    0.452830          364.150943               354.867925
# std     0.005306    0.502533          116.180131               155.699666
# min     0.001000    0.000000          200.000000               120.000000
# 25%     0.003000    0.000000          300.000000               240.000000
# 50%     0.005000    0.000000          400.000000               320.000000
# 75%     0.008000    1.000000          500.000000               468.000000
# max     0.026000    1.000000          500.000000               700.000000
#
#        error size  used elements  chain size  required size
# count   53.000000      53.000000   53.000000      53.000000
# mean    88.528302     293.660377  376.754717     373.150943
# std     59.740659     115.261399  116.409408     116.180131
# min      2.000000     120.000000  207.000000     209.000000
# ...

# %%
dataframe_negative = dataframe.loc[dataframe["error type"]==0,:].copy()
dataframe_negative.loc[:,"percent of elements used"] = dataframe_negative.loc[:,"used elements"]/dataframe_negative.loc[:,"number of elements real"]
dataframe_negative
# Out:
#       filename   time  error type  number of elements  \
# id
# 0    35.200-80  0.004           0                 200
# 1   55.400-160  0.009           0                 400
# 3    58.300-60  0.003           0                 300
# 5    68.400-80  0.005           0                 400
# 6    18.200-80  0.002           0                 200
# 11  20.300-120  0.003           0                 300
# 18  144.500-12  0.004           0                 500
# 19  25.500-200  0.006           0                 500
# 20   35.200-40  0.002           0                 200
# 21  68.400-160  0.006           0                 400
# 22   28.500-18  0.005           0                 500
# 23   55.300-60  0.003           0                 300
# 25  25.500-100  0.005           0                 500
# 26    9.200-40  0.002           0                 200
# 27  10.500-100  0.006           0                 500
# 29  55.300-120  0.003           0                 300
# ...

# %%
dataframe_negative.describe()
# Out:
#             time  error type  number of elements  number of elements real  \
# count  29.000000        29.0           29.000000                29.000000
# mean    0.004069         0.0          375.862069               286.482759
# std     0.001668         0.0          118.488011               122.395909
# min     0.001000         0.0          200.000000               120.000000
# 25%     0.003000         0.0          300.000000               180.000000
# 50%     0.004000         0.0          400.000000               240.000000
# 75%     0.005000         0.0          500.000000               400.000000
# max     0.009000         0.0          500.000000               498.000000
#
#        error size  used elements  chain size  required size  \
# count   29.000000      29.000000   29.000000      29.000000
# mean    89.379310     285.862069  385.931034     384.862069
# std     57.906584     121.315034  118.697374     118.488011
# ...

# %%
dataframe_positive = dataframe.loc[dataframe["error type"]==1,:].copy()
dataframe_positive.loc[:,"percent of elements used"] = dataframe_positive.loc[:,"used elements"]/dataframe_positive.loc[:,"number of elements"]
dataframe_positive
# Out:
#       filename   time  error type  number of elements  \
# id
# 2   58.300+120  0.015           1                 300
# 4     9.200+80  0.003           1                 200
# 7    55.300+30  0.007           1                 300
# 8    35.200+20  0.003           1                 200
# 9   55.400+160  0.018           1                 400
# 10   10.500+50  0.011           1                 500
# 12    9.200+20  0.004           1                 200
# 13  62.400+160  0.018           1                 400
# 14   18.200+80  0.008           1                 200
# 15   62.400+40  0.007           1                 400
# 16  10.500+200  0.026           1                 500
# 17   68.400+40  0.009           1                 400
# 24   35.200+80  0.002           1                 200
# 28  55.300+120  0.013           1                 300
# 32   55.400+40  0.008           1                 400
# 35  53.500+200  0.021           1                 500
# ...

# %%
dataframe_positive.describe()
# Out:
#             time  error type  number of elements  number of elements real  \
# count  24.000000        24.0           24.000000                24.000000
# mean    0.010000         1.0          350.000000               437.500000
# std     0.006338         0.0          114.208048               153.460093
# min     0.002000         1.0          200.000000               220.000000
# 25%     0.005500         1.0          275.000000               317.500000
# 50%     0.008000         1.0          350.000000               430.000000
# 75%     0.013500         1.0          425.000000               552.500000
# max     0.026000         1.0          500.000000               700.000000
#
#        error size  used elements  chain size  required size  \
# count   24.000000      24.000000   24.000000      24.000000
# mean    87.500000     303.083333  365.666667     359.000000
# std     63.125135     109.316022  115.113051     114.208048
# ...

# %%
benchmark
# Out:
#           filename   time  error type  number of elements  \
# id
# 30  ben.50000-5079  0.946           0               50000
#
#     number of elements real  error size  used elements  chain size  \
# id
# 30                    44921        5079          44877       50018
#
#     required size
# id
# 30          50009
